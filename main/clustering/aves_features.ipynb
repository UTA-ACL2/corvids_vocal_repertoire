# %%
# %pip install esp-aves pandas seaborn requests scikit-learn tqdm
# Out:
# Requirement already satisfied: esp-aves in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: pandas in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: seaborn in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: requests in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (2.32.4)
# Requirement already satisfied: scikit-learn in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: tqdm in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: torch>=2.0.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from esp-aves) (2.5.1)
# Requirement already satisfied: torchaudio>=2.0.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from esp-aves) (2.5.1)
# Requirement already satisfied: soundfile>=0.13.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from esp-aves) (0.13.1)
# Requirement already satisfied: pytest>=8.3.4 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from esp-aves) (8.4.1)
# Requirement already satisfied: onnxruntime>=1.20.1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from esp-aves) (1.22.0)
# Requirement already satisfied: numpy>=1.22.4 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from requests) (2025.6.15)
# Requirement already satisfied: scipy>=1.8.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: coloredlogs in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from onnxruntime>=1.20.1->esp-aves) (15.0.1)
# Requirement already satisfied: flatbuffers in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from onnxruntime>=1.20.1->esp-aves) (25.2.10)
# Requirement already satisfied: protobuf in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from onnxruntime>=1.20.1->esp-aves) (5.29.5)
# Requirement already satisfied: sympy in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from onnxruntime>=1.20.1->esp-aves) (1.13.1)
# Requirement already satisfied: exceptiongroup>=1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pytest>=8.3.4->esp-aves) (1.2.0)
# Requirement already satisfied: iniconfig>=1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pytest>=8.3.4->esp-aves) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pytest>=8.3.4->esp-aves) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pytest>=8.3.4->esp-aves) (2.19.1)
# Requirement already satisfied: tomli>=1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from pytest>=8.3.4->esp-aves) (2.2.1)
# Requirement already satisfied: six>=1.5 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: cffi>=1.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from soundfile>=0.13.0->esp-aves) (1.17.1)
# Requirement already satisfied: pycparser in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.13.0->esp-aves) (2.22)
# Requirement already satisfied: filelock in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (4.12.2)
# Requirement already satisfied: networkx in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (3.4.2)
# Requirement already satisfied: jinja2 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (3.1.6)
# Requirement already satisfied: fsspec in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from torch>=2.0.0->esp-aves) (3.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from sympy->onnxruntime>=1.20.1->esp-aves) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.20.1->esp-aves) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /data2/nitin/miniconda3/envs/denoise310/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->esp-aves) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
print(os.getcwd())
# Out:
# /data2/nitin/main/clustering

# %%
import pandas as pd
import os
from glob import glob

# Directory containing your wav files
data_dir = "../separation/american_crow_calls"

# Get all .wav files in the directory, sorted
fps = sorted(glob(os.path.join(data_dir, '*.wav')))

individuals = []
call_types = []
file_names = []
fps_sub = []

for fp in fps:
    bn = os.path.basename(fp)
    # Example filename: brachyrynchos_00001_1.wav
    parts = bn.split("_")

    # Make sure filename has at least 3 parts before .wav
    if len(parts) < 3:
        continue

    individual = parts[0]  # e.g., brachyrynchos
    call_type = parts[2].split(".")[0]  # e.g., 1 (after removing .wav)

    individuals.append(individual)
    call_types.append(call_type)
    file_names.append(bn)
    fps_sub.append(fp)

# Create a DataFrame from the collected data
df = pd.DataFrame({
    "filename": file_names,
    "filepath": fps_sub,
    "individual": individuals,
    "call_type": call_types
})

# Display the first few rows
print(df.head())
# Out:
#                     filename  \
# 0  brachyrynchos_00001_1.wav
# 1  brachyrynchos_00002_1.wav
# 2  brachyrynchos_00003_1.wav
# 3  brachyrynchos_00005_1.wav
# 4  brachyrynchos_00006_1.wav
#
#                                             filepath     individual call_type
# 0  ../separation/american_crow_calls/brachyryncho...  brachyrynchos         1
# 1  ../separation/american_crow_calls/brachyryncho...  brachyrynchos         1
# 2  ../separation/american_crow_calls/brachyryncho...  brachyrynchos         1
# 3  ../separation/american_crow_calls/brachyryncho...  brachyrynchos         1
# 4  ../separation/american_crow_calls/brachyryncho...  brachyrynchos         1

# %%
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from torchaudio.models import wav2vec2_model
import json
import torch.nn as nn

# %%
class Vox(Dataset):
    def __init__(self, dataset_dataframe, audio_sr, annotation_names):
        """ Dataset for vocalization classification with AVES

        Input
        -----
        dataset_dataframe (pandas dataframe): indicating the filepath, annotations and partition of a signal
        audio_sr (int): sampling rate expected by network
        annotation_name (list[str]): string corresponding to the annotation columns in the dataframe, e.g. ["call_type","recording_date"]
        """
        super().__init__()
        self.audio_sr = audio_sr
        self.annotation_names = annotation_names
        self.dataset_info = dataset_dataframe

    def __len__(self):
        return len(self.dataset_info)

    def get_one_item(self, idx):
      """ Load base audio """
      row = self.dataset_info.iloc[idx]
      x, sr = torchaudio.load(row["filepath"])
      if len(x.size()) == 2:
          x = x[0, :]
      if sr != self.audio_sr:
          x = torchaudio.functional.resample(x, sr, self.audio_sr)
      return x, row

    def __getitem__(self, idx):
        x, row = self.get_one_item(idx)
        out = {"x" : x, "filepath" : row['filepath'], "filename" : row['filename']}
        for k in self.annotation_names:
          out[k] = row[k]
        return out

def get_dataloader(dataset_dataframe, audio_sr, annotation_names):
    return DataLoader(
            Vox(dataset_dataframe, audio_sr, annotation_names),
            batch_size=1,
            shuffle=False,
            drop_last=False
        )

# %%
import requests

def download_file(url, filename):
    print(f"Downloading {filename}...")
    response = requests.get(url)
    response.raise_for_status()
    with open(filename, 'wb') as f:
        f.write(response.content)
    print(f"Saved {filename}")

download_file("https://storage.googleapis.com/esp-public-files/ported_aves/aves-base-bio.torchaudio.pt", "aves-base-bio.torchaudio.pt")
download_file("https://storage.googleapis.com/esp-public-files/ported_aves/aves-base-bio.torchaudio.model_config.json", "aves-base-bio.torchaudio.model_config.json")
# Out:
# Downloading aves-base-bio.torchaudio.pt...
# Saved aves-base-bio.torchaudio.pt
# Downloading aves-base-bio.torchaudio.model_config.json...
# Saved aves-base-bio.torchaudio.model_config.json

# %%
import sklearn.cluster
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
class AvesMeanEmbedding(nn.Module):
    """ Uses AVES Hubert to embed sounds and classify """
    def __init__(self, config_path, model_path, embedding_dim=768):
        super().__init__()
        # reference: https://pytorch.org/audio/stable/_modules/torchaudio/models/wav2vec2/utils/import_fairseq.html
        self.config = self.load_config(config_path)
        self.model = wav2vec2_model(**self.config, aux_num_out=None)
        self.model.load_state_dict(torch.load(model_path))
        self.audio_sr = 16000

    def load_config(self, config_path):
        with open(config_path, 'r') as ff:
            obj = json.load(ff)
        return obj

    def forward(self, sig):
        """
        Input
          sig (Tensor): (batch, time)
        Returns
          mean_embedding (Tensor): (batch, output_dim)
          logits (Tensor): (batch, n_classes)
        """
        # extract_feature in the sorchaudio version will output all 12 layers' output, -1 to select the final one
        out = self.model.extract_features(sig)[0][-1]
        mean_embedding = out.mean(dim=1) #over time
        return mean_embedding

# %%
import numpy as np
import pandas as pd
import torch
from tqdm import tqdm

def run_save_embeddings_only(dataset_dataframe, annotation_names, aves_sr=16000, output_csv="aves_embeddings_base_bio.csv"):

    print("~~ Setting up model")
    embedding_model = AvesMeanEmbedding(
        config_path="aves-base-bio.torchaudio.model_config.json",
        model_path="aves-base-bio.torchaudio.pt"
    )
    embedding_model.eval()
    if torch.cuda.is_available():
        embedding_model.cuda()

    print("~~ Setting up dataloader")
    dataloader = get_dataloader(dataset_dataframe, embedding_model.audio_sr, annotation_names)

    print(f"~~ Compute AVES embeddings")
    features = []
    filenames = []

    with torch.no_grad():
        for data_idx, data_dict in enumerate(tqdm(dataloader)):
            x = data_dict["x"]
            if torch.cuda.is_available():
                x = x.cuda()
            emb = embedding_model(x).cpu().numpy()  # shape: (batch_size, embedding_dim)
            
            # Assuming batch size=1 usually, but handle batch dimension anyway:
            for i in range(emb.shape[0]):
                features.append(emb[i])
                filenames.append(data_dict["filename"][i])

    # Convert list of embeddings to numpy array
    X = np.vstack(features)  # shape (n_samples, embedding_dim)

    # Prepare DataFrame with filenames and embeddings as columns
    df_out = pd.DataFrame(X, columns=[f"embedding_{i}" for i in range(X.shape[1])])
    df_out.insert(0, "filename", filenames)

    # Save to CSV
    df_out.to_csv(output_csv, index=False)
    print(f"Saved embeddings to {output_csv}")

    return df_out

# %%
df_embeddings = run_save_embeddings_only(df, annotation_names=[])
# Out:
# ~~ Setting up model
# /tmp/ipykernel_379950/3629602379.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(model_path))
# ~~ Setting up dataloader
# ~~ Compute AVES embeddings
# 100%|██████████| 37665/37665 [1:08:17<00:00,  9.19it/s]
# Saved embeddings to aves_embeddings_base_bio.csv
